# %% [markdown]
# # 05_compare_label_models

# %% [markdown]
# Compare cross-encoder vs hierarchical transformer.
#
# (Full code was provided earlier in conversation; this file is a runnable placeholder scaffold.)
